# %%
import visens as vs

# Diffraction experiment
file1 = "data/nicos_00000490.hdf"
# Reflectometry experiment
file2 = "data/nicos_00000490.hdf"

# %%
# Plot a 2D image of the integrated detector counts
vs.image(file2, log=True)
